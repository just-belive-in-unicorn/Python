# %% [markdown]
# # I. Змінні та памʼять.

# %% [markdown]
# 1. Створити змінні, що посилаються на два цілих числа, що однакові за значенням, де значення належить проміжку від -5 до 256. Перевірте, чи будуть ці змінні рівні тільки за значенням або ж ще будуть посилатися на один і той самий обʼєкт в памʼяті? Наведіть код та дайте текстову відповідь нижче.

# %%
first_var = 1;
scnd_var = 1;

print(first_var == scnd_var) # True
print(first_var is scnd_var) # True
# Out:
# True
# True

# %% [markdown]
# Змінні будуть рівні за значенням, бо ми надали їм однакові значення в коді. Вони також будуть ссилатись на один об'єкт, бо за принципом кешування цілочисельних змінних всі змінні, що мають значення від -5 до 256 ссилаються на один об'єкт

# %% [markdown]
# 2. За допомогою якої функції можна перевірити належність змінної до вказаного типу даних (напр. чи змінна True посилається на значення булевого та цілочисленого типу)?

# %%
x = True
print(isinstance(x, bool))
# Out:
# True

# %% [markdown]
# # II. Цілі числа та числа з рухомою комою

# %% [markdown]
# 3. Створити дві змінні, що посилаються на будь-які ціле число та число з рухомою комою та продемонструвати такі арифметичні операції: додавання, віднімання, ділення, множення, ділення без залишку, ділення по модулю, приведення до ступеню. Всі результати операцій вивести на екран.

# %%
a = 3
b = 0.5

# Обчислення
addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b
floor_division = a // b
mod = a % b
power = a ** b

# Виведення результатів
print("Додавання: ", a, " + ", b, " = ", addition)
print("Віднімання: ", a, " - ", b, " = ", subtraction)
print("Множення: ", a, " * ", b, " = ", multiplication)
print("Ділення: ", a, " / ", b, " = ", division)
print("Цілочисельне ділення: ", a, " // ", b, " = ", floor_division)
print("Залишок від ділення: ", a, " % ", b, " = ", mod)
print("Степінь: ", a, " ** ", b, " = ", power)
# Out:
# Додавання:  3  +  0.5  =  3.5
# Віднімання:  3  -  0.5  =  2.5
# Множення:  3  *  0.5  =  1.5
# Ділення:  3  /  0.5  =  6.0
# Цілочисельне ділення:  3  //  0.5  =  6.0
# Залишок від ділення:  3  %  0.5  =  0.0
# Степінь:  3  **  0.5  =  1.7320508075688772

# %% [markdown]
# 4. Використовуючи змінні з вправи 3, продемонструйте механізм явного перетворення типів, де числа з рухомою комою перетворюються на цілі числа. Також визначте змінну, що посилається на значення булевого типу і спробуйте явно привести її до цілого числа.

# %%
int_b = int(b)
x = True
int_x = int(x)
print(isinstance(int_x, int)) # True
print(isinstance(int_b, int)) # True
# Out:
# True
# True

# %% [markdown]
# # IІІ. Рядки (String).

# %% [markdown]
# 5. Створити пустий рядок двома різними способами.

# %%
string1 = ""
string2 = str()

# %% [markdown]
# 6. Створити рядок з апострофом. Зробити його сирим. Вивести обидва рядка на екран.

# %%
str1 = "I'm Nastya"
str2 = r"I'm Nastya"

print(str1)
print(str2)
# Out:
# I'm Nastya
# I'm Nastya

# %% [markdown]
# 7. Створити змінну, що буде посилатися на Ваше прізвище латинкою. Створити форматований рядок, який буде мати вигляд "My surname is ______", де на місці нижніх підкреслень буде Ваше прізвище зі змінної.

# %%
surname = "Dernova"
formatted_str = f"My surname is " + surname
print(formatted_str)
# Out:
# My surname is Dernova

# %% [markdown]
# 8. Маючи рядок "My dog is crazy." перетворити його на список ["my", "dog", "is", "crazy"]

# %%
text = "My dog is crazy."
word_list = text.lower().strip('.').split()
print(word_list)
# Out:
# ['my', 'dog', 'is', 'crazy']

# %% [markdown]
# # IV. Робота зі списками.

# %% [markdown]
# 9. Створити список двома різними за синтаксисом способами. За допомогою вбудованої функції обчисліть довжину одного з них.

# %%
list1 = [1, 2, 3, 4]
list2 = list((5, 6, 7, 8))
length = len(list2)
print(length)
# Out:
# 4

# %% [markdown]
# 10. Створіть два списка та за допомогою спеціального методу додайте другий з них в якості останнього елемента першого.

# %%
list1 = list((1, 2, 3, 4))
list2 = list((5, 6, 7))
list1.append(list2)
print(list1)
# Out:
# [1, 2, 3, 4, [5, 6, 7]]

# %% [markdown]
# 11. Створіть список, де елементами цього списку також є списки. Отримай перший елемент з останнього рядка та виведи значення на екран.

# %%
my_list = [ [1, 2, 3]
           ,[4, 5, 6]
           ,[7, 8, 9]]
el = my_list[-1][0]
print(el)
# Out:
# 7

# %% [markdown]
# 12. Створіть список з десяти елементів різного типу. Отримайте всі елементи, окрім двох перших та двох останніх та збережіть їх в новій змінній.

# %%
my_list = [1, 2, "me", {"hi",}, [3, 4], 1.2, True, False, None, 0]
cropped = my_list[2:-2]
print(cropped)
# Out:
# ['me', {'hi'}, [3, 4], 1.2, True, False]

# %% [markdown]
# # V. Робота з кортежами.

# %% [markdown]
# 14. Створити кортеж з один елементом.

# %%
tuple = ("element",)

# %% [markdown]
# 15. Порівняйте список та кортеж. Назвіть схожості та відмінності, випадки використання.

# %% [markdown]
# Схожості: обидва типи є послідовними та ітерованими, мають окрему функцію для створення об'єкту, можуть містити будь-які типи даних, мають функцію len()
# Відмінності: список - змінний тип, кортеж - незмінний. Кортеж займає менше пам'яті та копіюється швидше, ніж список
# Використання:
# Кортеж використовується коли потрібно створити впорядковану множину незмінних значень (констант)
# Список використвується в якості динамічного масиву

# %% [markdown]
# 16. Створіть кортеж з 11ти елементів чисел з рухомою комою та отримайте кожен парний за індексом елемент в зворотньому порядку. Наприклад, маючи (1.2, 2.3, 3.3, 4.3, 5.3, 6.3, 7.3, 8.3, 9.3, 0.3), отримати (0.3, 8.3, 6.3, 4.3, 2.3). Результат збережіть в нову змінну та виведіть на екран.

# %%
tuple = (1.2, 2.3, 3.3, 4.3, 5.3, 6.3, 7.3, 8.3, 9.3, 0.3)
cropped = tuple[-1::-2]
print(cropped)
# Out:
# (0.3, 8.3, 6.3, 4.3, 2.3)

# %% [markdown]
# # VI. Множини (Set).

# %% [markdown]
# 17. Створити множину без елементів. Після цого за допомогою методу додайте кілька різних елементів до множини. Чи множини є змінним типом даних?

# %%
my_set = set()
my_set.add(1)
my_set.add(2.0)
my_set.add(True)
my_set.add("Str")

# %% [markdown]
# Так, множини є змінним типом даних

# %% [markdown]
# 18. Створити множину, маючи список my_list = [1, 1, 2, 67, 67, 8, 9]. Пояснити, чому "зникли" деякі елементи.

# %%
my_list = [1, 1, 2, 67, 67, 8, 9]
my_set = set(my_list)
print(my_set)

# %% [markdown]
# Множини не можуть містити в собі дублікати

# %% [markdown]
# 19. Створіть дві множини. Продемонстуйте над ними операції: обʼєднання, різниці, пересічі та симетричної різниці. Використовуйте методи, що не змінюють множини, а створюють нові.

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# Об'єднання
union_set = set1.union(set2)
print("Об'єднання: ", union_set)

# Перетин
intersection_set = set1.intersection(set2)
print("Перетин: ", intersection_set)

# Різниця
difference_set = set1.difference(set2)
print("Різниця (set1 - set2): ", difference_set)

# Симетрична різниця
symmetric_difference_set = set1.symmetric_difference(set2)
print("Симетрична різниця: ", symmetric_difference_set)
# Out:
# Об'єднання:  {1, 2, 3, 4, 5, 6, 7, 8}
# Перетин:  {4, 5}
# Різниця (set1 - set2):  {1, 2, 3}
# Симетрична різниця:  {1, 2, 3, 6, 7, 8}

# %% [markdown]
# # VII. Словники (Dictionary).

# %% [markdown]
# 20. Створіть пустий словник. До нього додайте чотири пари елементів такі, щоб їхні ключі були різних типів. Чи може список бути ключем? Чому?

# %%
dictionary = dict()
dictionary[1] = "int"
dictionary["hi"] = "word"
dictionary[3.14] = "Pi"
dictionary[(1, 2, 3)] = "Tuple"
print(dictionary)
# Out:
# {1: 'int', 'hi': 'word', 3.14: 'Pi', (1, 2, 3): 'Tuple'}

# %% [markdown]
# Список не може бути ключем, бо ключами можуть бути тільки об'єкти незмінних типів даних

# %% [markdown]
# 21. Створіть словник, де значенням в одній з пар теж буде словник, який теж має вкладений словник. Виведіть на екран значення, що міститься в словнику, що знаходиться на найнижчому рівні ієрархії вкладеності (найбільш внутрішній).

# %%
nested_dictionary = {
    "first_level": {
        "second_level": {
                "key": "value"
        }
    }
}

print(nested_dictionary["first_level"]["second_level"]["key"])
# Out:
# value

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
